# %%
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
df.head(15)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# 5     -114.58     33.63                29.0       1387.0           236.0
# 6     -114.58     33.61                25.0       2907.0           680.0
# 7     -114.59     34.83                41.0        812.0           168.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 9     -114.60     34.83                46.0       1497.0           309.0
# 10    -114.60     33.62                16.0       3741.0           801.0
# 11    -114.60     33.60                21.0       1988.0           483.0
# ...

# %%
df.tail(15)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16985    -124.19     40.77                30.0       2975.0           634.0
# 16986    -124.19     40.73                21.0       5694.0          1056.0
# 16987    -124.21     41.77                17.0       3461.0           722.0
# 16988    -124.21     41.75                20.0       3810.0           787.0
# 16989    -124.21     40.75                32.0       1218.0           331.0
# 16990    -124.22     41.73                28.0       3003.0           699.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16992    -124.23     40.81                52.0       1112.0           209.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# ...

# %%
# first upload Salaries.csv
df=pd.read_csv("Salaries.csv")

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df['rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.phd.describe
# Out:
# <bound method NDFrame.describe of 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64>

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean()
# Out:
# <ipython-input-19-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.salary.quantile(0.25)
# Out:
# 88612.5

# %%
df.phd.quantile(0.25)
# Out:
# 10.25

# %%
df.salary.quantile(0.50)
# Out:
# 104671.0

# %%
df.phd.quantile(0.75)
# Out:
# 27.75

# %%
df.salary.quantile(0.75)
# Out:
# 126774.75

# %%
df.std()
# Out:
# <ipython-input-26-ce97bb7eaef8>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df_50=df.head(50)

# %%
df_50.mean()
# Out:
# <ipython-input-28-abcf5df04292>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_50.mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.head(50).mean()
# Out:
# <ipython-input-29-56442511a41d>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.head(50).mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
# selectin a column
df.salary   # does not wprk if column name contains blank space or dot (eg."no.of column")
#   for that enclose column name inside square bracket.
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df["salary"]   # will work if column name has blank space of dot('eg.No.of columns')
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
result1=df.salary
result1
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
# Data structures in pandas:1.  seriess,2. Dataframe

# %%
type(result1)
# Out:
# pandas.core.series.Series

# %%
result2=df[['salary']]

# %%
result2
# Out:
#     salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# 74  104542
# 75  124312
# 76  109954
# 77  109646
#
# [78 rows x 1 columns]

# %%
type(result2)
# Out:
# pandas.core.frame.DataFrame

# %%
result2=df[["salary","phd"]]

# %%
result2
# Out:
#     salary  phd
# 0   186960   56
# 1    93000   12
# 2   110515   23
# 3   131205   40
# 4   104800   20
# ..     ...  ...
# 73  105450   18
# 74  104542   19
# 75  124312   17
# 76  109954   28
# 77  109646   23
#
# [78 rows x 2 columns]

# %%
type(result2)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
# Extract particular columns in a new datafram
newdf=df[['salary','service','phd']]
newdf
# Out:
#     salary  service  phd
# 0   186960       49   56
# 1    93000        6   12
# 2   110515       20   23
# 3   131205       31   40
# 4   104800       18   20
# ..     ...      ...  ...
# 73  105450       10   18
# 74  104542        6   19
# 75  124312       17   17
# 76  109954       14   28
# 77  109646       15   23
#
# [78 rows x 3 columns]

# %%
df['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df.tail(10)

# %%
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.phd.count()
# Out:
# 78

# %%
df.phd.mean()
# Out:
# 19.705128205128204

# %%
df["phd"].count()
# Out:
# 78

# %%
# i  rank 3 value: asso asst prof.group by this and find mean of each category
df.groupby(["rank"]).mean()    #group by rank and finds mean of all nueric column
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby(["discipline"]).count()
# Out:
#             rank  phd  service  sex  salary
# discipline
# A             36   36       36   36      36
# B             42   42       42   42      42

# %%
df.groupby(["discipline","rank"]).count()
# Out:
#                       phd  service  sex  salary
# discipline rank
# A          AssocProf    5        5    5       5
#            AsstProf     8        8    8       8
#            Prof        23       23   23      23
# B          AssocProf    8        8    8       8
#            AsstProf    11       11   11      11
#            Prof        23       23   23      23

# %%
df.groupby(["discipline","rank","sex"]).count()
# Out:
#                              phd  service  salary
# discipline rank      sex
# A          AssocProf Female    4        4       4
#                      Male      1        1       1
#            AsstProf  Female    6        6       6
#                      Male      2        2       2
#            Prof      Female    8        8       8
#                      Male     15       15      15
# B          AssocProf Female    6        6       6
#                      Male      2        2       2
#            AsstProf  Female    5        5       5
#                      Male      6        6       6
#            Prof      Female   10       10      10
#                      Male     13       13      13

# %%
df.groupby(["discipline","rank","sex","phd"]).count()
# Out:
#                                  service  salary
# discipline rank      sex    phd
# A          AssocProf Female 10         1       1
#                             13         1       1
#                             25         1       1
#                             26         1       1
#                      Male   20         1       1
# ...                                  ...     ...
# B          Prof      Male   28         1       1
#                             35         2       2
#                             39         1       1
#                             45         1       1
#                             56         1       1
#
# [68 rows x 2 columns]

# %%
df.groupby(["discipline","rank","sex"]).mean()
# Out:
#                                    phd    service         salary
# discipline rank      sex
# A          AssocProf Female  18.500000  15.500000   72128.500000
#                      Male    20.000000  17.000000   81285.000000
#            AsstProf  Female   4.833333   2.500000   72933.333333
#                      Male     3.000000   1.000000   79000.000000
#            Prof      Female  26.500000  16.125000  109631.875000
#                      Male    28.933333  22.733333  113164.400000
# B          AssocProf Female  13.500000   8.833333   99435.666667
#                      Male    10.500000   7.500000  113404.000000
#            AsstProf  Female   6.600000   2.600000   84189.800000
#                      Male     4.666667   2.000000   88224.000000
#            Prof      Female  21.500000  17.900000  131836.200000
#                      Male    29.538462  25.846154  137989.076923

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
grouped=df.groupby('rank')   # saving in variable grouped

# %%
for g in grouped:     # to disply records of grouped variable
  print(g)
# Out:
# ('AssocProf',          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 41  AssocProf          A   13        8  Female   74830
# 47  AssocProf          B   11       11  Female  103613
# 54  AssocProf          A   25       22  Female   62884
# 56  AssocProf          A   10        8  Female   77500
# 59  AssocProf          B   12       10  Female  103994
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 64  AssocProf          A   26       24  Female   73300
# 71  AssocProf          B   12        9  Female   71065
# 74  AssocProf          B   19        6  Female  104542)
# ('AsstProf',         rank discipline  phd  service     sex  salary
# 12  AsstProf          B    1        0    Male   88000
# 16  AsstProf          B    8        3    Male   75044
# ...

# %%
df[df.salary>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df.shape
# Out:
# (78, 6)

# %%
df.shape[0]
# Out:
# 78

# %%
df.shape[1]
# Out:
# 6

# %%
df[df.salary>120000].shape[0]    # count of prof having sal > 120000
# Out:
# 25

# %%
df[df.salary>120000].count()
# Out:
# rank          25
# discipline    25
# phd           25
# service       25
# sex           25
# salary        25
# dtype: int64

# %%
newdf=df[(df['sex']=='male') | (df['salary']>150000)]
newdf
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 27  Prof          A   45       43    Male  155865
# 31  Prof          B   22       21    Male  155750
# 44  Prof          B   23       19  Female  151768
# 72  Prof          B   24       15  Female  161101

# %%
#newdf.count()
#or
newdf.shape[0]
# Out:
# 9

# %%
df[df['rank']!='prof'].shape[0]
# Out:
# 78

# %%
df.iloc[44]  # iloc -> index llocation for row
# Out:
# rank            Prof
# discipline         B
# phd               23
# service           19
# sex           Female
# salary        151768
# Name: 44, dtype: object

# %%
df.iloc[1:4,0:3]  # row 1 to 3, col 0 to 2
# Out:
#    rank discipline  phd
# 1  Prof          A   12
# 2  Prof          A   23
# 3  Prof          A   40
